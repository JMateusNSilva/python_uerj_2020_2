# %% [markdown]
# <a href="https://colab.research.google.com/github/JMateusNSilva/python_uerj_2020_2/blob/master/exerc%C3%ADcios/aula05_02_10_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Aula 05** - dia 02 de novembro de 2020
#
# **Professores:**
#
#    * Helena Malbouis
#    * Dilson de Jesus Damião
#
# **Aluno:** José Mateus Nobre da Silva

# %%
# declarações para instalar e importar o módulo Turtle no âmbito do Google Colab.
# !pip3 install ColabTurtle
#import ColabTurtle
# Out:
# Collecting ColabTurtle
#   Downloading https://files.pythonhosted.org/packages/49/01/6da7091c2c6c917cce99c000b89acb6aa27b66ef6eafc0c0ccf59b98694f/ColabTurtle-2.0.0.tar.gz
# Building wheels for collected packages: ColabTurtle
#   Building wheel for ColabTurtle (setup.py) ... done
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.0.0-cp36-none-any.whl size=4032 sha256=1e4bd39060ffbe3a005ee92a54d6737139799feeea37e30fed806594f04ba090
#   Stored in directory: /root/.cache/pip/wheels/a8/29/ec/ad346f0042ae467cc74f4378916348faf975b07890651dcae7
# Successfully built ColabTurtle
# Installing collected packages: ColabTurtle
# Successfully installed ColabTurtle-2.0.0

# %%
import ColabTurtle.Turtle as joana
joana.initializeTurtle()
joana.forward(150)
joana.left(90)
joana.forward(130)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="100.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="100.0" x2="270.0" y2="100.00000000000001" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#
#       <g visibility=visible transform="rotate(90,270.0,100.00000000000001) translate(270.0, 100.00000000000001)">
#         <circle stroke="white" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:white;stroke:white;stroke-width:2"/>
#       </g>
#
#       </svg>

# %%
import ColabTurtle.Turtle as teca   # Cria uma tartaruga, atribui a teca
teca.initializeTurtle()
teca.color("blue")          # O método color diz a Teca para mudar sua cor (atributo)
teca.width(3)               # O método width faz Teca ajustar a largura da caneta (atributo)

teca.forward(50)
teca.left(120)
teca.forward(50)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:blue;stroke-width:3"/><line x1="400.0" y1="200.0" x2="356.69872981077805" y2="225.0" stroke-linecap="round" style="stroke:blue;stroke-width:3"/>
#
#       <g visibility=visible transform="rotate(60,356.69872981077805,225.0) translate(356.69872981077805, 225.0)">
#         <circle stroke="blue" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:blue;stroke:blue;stroke-width:2"/>
#       </g>
#
#       </svg>

# %%
import ColabTurtle.Turtle as teca         # Cria a intância Teca
teca.initializeTurtle()           # Configura os atributos de Teca
teca.color('yellow')
teca.width(5)
#teca.window_size=(400,500)

# Fazer Teca desenhar um triângulo equilátero:
teca.forward(80)
teca.left(120)
teca.forward(80)
teca.left(120)
teca.forward(80)
teca.left(120)                    # completa o triangulo

teca.right(180)                   # Fazer Teca dar meia volta
teca.forward(80)                  # Movê-lá para longe da origem

# Criar uma nova instância de Tartaruga:
import ColabTurtle.Turtle as joana
joana.initializeTurtle()            # Configura os atributos de Joana
joana.color('purple')           # Cria a instância Joana

# Fazer Joana Desenhar um quadrado:
joana.forward(50)
joana.left(90)
joana.forward(50)
joana.left(90)
joana.forward(50)
joana.left(90)
joana.forward(50)
joana.left(90)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="170.0" stroke-linecap="round" style="stroke:yellow;stroke-width:5"/><line x1="400.0" y1="170.0" x2="330.7179676972449" y2="210.0" stroke-linecap="round" style="stroke:yellow;stroke-width:5"/><line x1="330.7179676972449" y1="210.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:yellow;stroke-width:5"/><line x1="400.0" y1="250.0" x2="400.0" y2="330.0" stroke-linecap="round" style="stroke:yellow;stroke-width:5"/>
#
#       <g visibility=visible transform="rotate(0,400.0,330.0) translate(400.0, 330.0)">
#         <circle stroke="yellow" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:yellow;stroke:yellow;stroke-width:2"/>
#       </g>
#
#       </svg>
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="400.0" y1="200.0" x2="350.0" y2="200.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="350.0" y1="200.0" x2="350.0" y2="250.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="350.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/>
#
#       <g visibility=visible transform="rotate(180,400.0,250.0) translate(400.0, 250.0)">
#         <circle stroke="purple" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:purple;stroke:purple;stroke-width:2"/>
#       </g>
#
#       </svg>

# %%
for f in ['José', 'Zoe', 'Bruno', 'Angélica', 'Zacarias', 'Thandi', 'Paris']:
    convite = 'Oi ' + f + ". Você está convidado para minha festa no Sábado!"
    print(convite)
# Out:
# Oi José. Você está convidado para minha festa no Sábado!
# Oi Zoe. Você está convidado para minha festa no Sábado!
# Oi Bruno. Você está convidado para minha festa no Sábado!
# Oi Angélica. Você está convidado para minha festa no Sábado!
# Oi Zacarias. Você está convidado para minha festa no Sábado!
# Oi Thandi. Você está convidado para minha festa no Sábado!
# Oi Paris. Você está convidado para minha festa no Sábado!

# %%
import ColabTurtle.Turtle as joana
joana.initializeTurtle()
for i in [0, 1, 2, 3]:
    joana.forward(50)
    joana.left(90)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="200.0" x2="350.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="350.0" y1="200.0" x2="350.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="350.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#
#       <g visibility=visible transform="rotate(180,400.0,250.0) translate(400.0, 250.0)">
#         <circle stroke="white" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:white;stroke:white;stroke-width:2"/>
#       </g>
#
#       </svg>

# %%
import ColabTurtle.Turtle as joana
joana.initializeTurtle()
for i in range(4):
    joana.forward(50)
    joana.left(90)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="200.0" x2="350.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="350.0" y1="200.0" x2="350.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="350.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#
#       <g visibility=visible transform="rotate(180,400.0,250.0) translate(400.0, 250.0)">
#         <circle stroke="white" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:white;stroke:white;stroke-width:2"/>
#       </g>
#
#       </svg>

# %%
import ColabTurtle.Turtle as joana
joana.initializeTurtle()
cores = ['yellow', 'red', 'purple', 'blue']   # Valid_colors = ('white', 'yellow', 'orange', 'red', 'green', 'blue', 'purple', 'grey', 'black')
for i in cores:
    joana.color(i)
    joana.forward(50)
    joana.left(90)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:yellow;stroke-width:4"/><line x1="400.0" y1="200.0" x2="350.0" y2="200.0" stroke-linecap="round" style="stroke:red;stroke-width:4"/><line x1="350.0" y1="200.0" x2="350.0" y2="250.0" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="350.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/>
#
#       <g visibility=visible transform="rotate(180,400.0,250.0) translate(400.0, 250.0)">
#         <circle stroke="blue" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:blue;stroke:blue;stroke-width:2"/>
#       </g>
#
#       </svg>

# %% [markdown]
# **Exercício 1:** Feito em arquivo txt e adicionado no github.

# %% [markdown]
# **Exercício 02** - Faça modificações similares para permitir que o usuário mude a cor da tartaruga durante a execução do programa.
#
#
# 1.   Faça o mesmo para a largura da caneta da tartaruga. Dica: seu diálogo com o usuário retornará uma string, mas o método pensize(width no Google Colab) espera que seu argumento seja um **int**. Então, você precisará converter a **string** em um **int** antes de passá-la para **pensize**.

# %%
# declarações para instalar e importar o módulo Turtle no âmbito do Google Colab.
# !pip3 install ColabTurtle
# Out:
# Collecting ColabTurtle
#   Downloading https://files.pythonhosted.org/packages/49/01/6da7091c2c6c917cce99c000b89acb6aa27b66ef6eafc0c0ccf59b98694f/ColabTurtle-2.0.0.tar.gz
# Building wheels for collected packages: ColabTurtle
#   Building wheel for ColabTurtle (setup.py) ... done
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.0.0-cp36-none-any.whl size=4032 sha256=c8a3161a531d4ce301285dbfb65672c0b005fa834ffc34bbd05a09ca5f047f6b
#   Stored in directory: /root/.cache/pip/wheels/a8/29/ec/ad346f0042ae467cc74f4378916348faf975b07890651dcae7
# Successfully built ColabTurtle
# Installing collected packages: ColabTurtle
# Successfully installed ColabTurtle-2.0.0

# %%
import ColabTurtle.Turtle as mateus
mateus.initializeTurtle()

for i in range(4):
    print('Escolha um das cores abaixo para compor cada lado do seu quadrado.')
    print('white, yellow, orange, red, green, blue, purple, gray, black. ')
    cor = input('Digite a cor escolhida para linha do quadrado: ')

    mateus.color(cor)
    mateus.forward(150)
    mateus.left(90)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="100.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="100.0" x2="250.0" y2="100.00000000000001" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="250.0" y1="100.00000000000001" x2="250.0" y2="250.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="250.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:red;stroke-width:4"/>
#
#       <g visibility=visible transform="rotate(180,400.0,250.0) translate(400.0, 250.0)">
#         <circle stroke="red" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:red;stroke:red;stroke-width:2"/>
#       </g>
#
#       </svg>
# Escolha um das cores abaixo para compor cada lado do seu quadrado.
# white, yellow, orange, red, green, blue, purple, gray, black.
# Digite a cor escolhida para linha do quadrado: white
# Escolha um das cores abaixo para compor cada lado do seu quadrado.
# white, yellow, orange, red, green, blue, purple, gray, black.
# Digite a cor escolhida para linha do quadrado: blue
# Escolha um das cores abaixo para compor cada lado do seu quadrado.
# white, yellow, orange, red, green, blue, purple, gray, black.
# Digite a cor escolhida para linha do quadrado: green
# Escolha um das cores abaixo para compor cada lado do seu quadrado.
# white, yellow, orange, red, green, blue, purple, gray, black.
# Digite a cor escolhida para linha do quadrado: red

# %%
tam_linha1 = int(input('Insira um valor inteiro para a expessura da sua primeira linha. '))
tam_linha2 = int(input('Insira um valor inteiro para a expessura da sua segunda linha. '))
tam_linha3 = int(input('Insira um valor inteiro para a expessura da sua terceira linha. '))
tam_linha4 = int(input('Insira um valor inteiro para a expessura da sua quarta linha. '))

import ColabTurtle.Turtle as mateus
mateus.initializeTurtle()

for i in [tam_linha1,tam_linha2,tam_linha3,tam_linha4]:
    mateus.width(i)
    mateus.forward(100)
    mateus.left(90)
# Out:
# Insira um valor inteiro para a expessura da sua primeira linha. 1
# Insira um valor inteiro para a expessura da sua segunda linha. 3
# Insira um valor inteiro para a expessura da sua terceira linha. 5
# Insira um valor inteiro para a expessura da sua quarta linha. 7
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="150.0" x2="300.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:3"/><line x1="300.0" y1="150.0" x2="300.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:5"/><line x1="300.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:7"/>
#
#       <g visibility=visible transform="rotate(180,400.0,250.0) translate(400.0, 250.0)">
#         <circle stroke="white" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:white;stroke:white;stroke-width:2"/>
#       </g>
#
#       </svg>

# %% [markdown]
# **Exercício 3** - Investiguem os métodos e atributos do módulo turtle (ColabTurtle no Google Colab)

# %% [markdown]
# Veja: https://docs.python.org/2/library/turtle.html#turtle.forward

# %% [markdown]
# **Exercício 4** - Desenhe um quadrado, usando a forma de tartaruga, ao invés de flecha, para desenhar (caso esteja no Google Colab, não precisa mudar a forma).
# 1.  mude a velocidade com que a tartaruga faz o desenho.

# %%
import ColabTurtle.Turtle as mateus
mateus.initializeTurtle()
mateus.speed(10)
mateus.color('orange')
mateus.bgcolor('white')
mateus.width(2)

for i in range(4):
    mateus.forward(150)
    mateus.left(90)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="white"/>
#         <line x1="400" y1="250" x2="400.0" y2="100.0" stroke-linecap="round" style="stroke:orange;stroke-width:2"/><line x1="400.0" y1="100.0" x2="250.0" y2="100.00000000000001" stroke-linecap="round" style="stroke:orange;stroke-width:2"/><line x1="250.0" y1="100.00000000000001" x2="250.0" y2="250.0" stroke-linecap="round" style="stroke:orange;stroke-width:2"/><line x1="250.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:orange;stroke-width:2"/>
#
#       <g visibility=visible transform="rotate(180,400.0,250.0) translate(400.0, 250.0)">
#         <circle stroke="orange" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:orange;stroke:orange;stroke-width:2"/>
#       </g>
#
#       </svg>

# %% [markdown]
# **Exercício 5**- Sabendo que o ângulo interno da ponta de uma estrela de 5 pontas é de 36 graus, desenhe uma estrela.

# %%
import ColabTurtle.Turtle as mateus
mateus.initializeTurtle()


mateus.left(90)
for i in range(5):
    mateus.left(144)
    mateus.forward(200)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="561.8033988749895" y2="367.55705045849464" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="561.8033988749895" y1="367.55705045849464" x2="500.0" y2="177.34574719946394" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="500.0" y1="177.34574719946394" x2="438.19660112501055" y2="367.5570504584947" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="438.19660112501055" y1="367.5570504584947" x2="600.0" y2="250.00000000000003" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="600.0" y1="250.00000000000003" x2="400.0" y2="250.00000000000006" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#
#       <g visibility=visible transform="rotate(90,400.0,250.00000000000006) translate(400.0, 250.00000000000006)">
#         <circle stroke="white" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:white;stroke:white;stroke-width:2"/>
#       </g>
#
#       </svg>

# %% [markdown]
# **Exercício 06** - Sabendo o ângulo interno da ponta de uma estrela, desenhe quatro estrelas em uma janela, com uma certa distância entre elas. Dica: use a função penup( ) e pendown( ) do módulo turtle.

# %%
import ColabTurtle.Turtle as mateus
mateus.initializeTurtle()

def estrela():
    mateus.left(90)
    for i in range(5):
        mateus.left(144)
        mateus.forward(200)

def mover(mateus, dist):
    mateus.penup()
    mateus.forward(dist)
    mateus.pendown()

mateus.window_size = (900,900)

mover(mateus, -200)
estrela()

mover(mateus,200)
estrela()

mover(mateus,200)
estrela()
# Out:
#       <svg width="900" height="900">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400.00000000000006" y1="450.0" x2="561.8033988749895" y2="567.5570504584946" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="561.8033988749895" y1="567.5570504584946" x2="500.0" y2="377.34574719946386" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="500.0" y1="377.34574719946386" x2="438.19660112501055" y2="567.5570504584946" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="438.19660112501055" y1="567.5570504584946" x2="600.0" y2="449.9999999999999" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="600.0" y1="449.9999999999999" x2="400.0" y2="449.9999999999999" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="200.0" y1="449.9999999999999" x2="317.5570504584946" y2="288.1966011250104" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="317.5570504584946" y1="288.1966011250104" x2="127.34574719946389" y2="349.9999999999999" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="127.34574719946389" y1="349.9999999999999" x2="317.5570504584946" y2="411.80339887498934" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="317.5570504584946" y1="411.80339887498934" x2="199.99999999999994" y2="249.9999999999999" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="199.99999999999994" y1="249.9999999999999" x2="199.99999999999994" y2="449.9999999999999" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="199.99999999999994" y1="649.9999999999999" x2="38.19660112501043" y2="532.4429495415053" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="38.19660112501043" y1="532.4429495415053" x2="99.99999999999991" y2="722.654252800536" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="99.99999999999991" y1="722.654252800536" x2="161.80339887498937" y2="532.4429495415053" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="161.80339887498937" y1="532.4429495415053" x2="-8.526512829121202e-14" y2="650.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="-8.526512829121202e-14" y1="650.0" x2="199.99999999999991" y2="650.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#
#       <g visibility=visible transform="rotate(-90,199.99999999999991,650.0) translate(199.99999999999991, 650.0)">
#         <circle stroke="white" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:white;stroke:white;stroke-width:2"/>
#       </g>
#
#       </svg>

# %% [markdown]
# **Exercícios - Parte 2:**
#
# Questão 01 - Escreva um conjunto apropriadamente geral de funções que possam desenhar flores.

# %%
def polyline(t, n, length, ang):
    """ Desenha n segmentos de linha com o tamanho e angulo
    (em graus) dados entre eles. t é uma tartaruga"""
    for i in range(n):
        t.forward(int(length))
        t.left(ang)

def arc(t, r, ang):
    arc_length = 2 * math.pi * r * ang / 360
    n = int(arc_length / 3) + 1
    step_length = arc_length / n 
    step_ang = float(ang) / n
    polyline(t, n, step_length, step_ang)
def petala(t, r, ang):
    """Desenha uma petola usando dois arcos.

      t -> é uma tartaruga
      r -> é o raio de um arco
    ang -> é o angulo (em graus) do arco
    """
    for i in range(2):
        arc(t, r, ang)
        t.left(180-ang)


def flor(t, n, r, ang):
    """ Desenha uma flor com n petolas.

    t -> tartaruga
    n -> números de petalas
    r -> raio do arco
    ang -> angulo (em graus) que o arco tem
    """
    for i in range(n):
        petala(t, r, ang)
        t.left(360/n)
    

#length1 e length 2 aceitam somente valores positivos
#Observe que a screen (tela) o valor (0,0) para (x,y) indica o canto superior esquerdo
#da screen.
def mover(t, length1,length2):
    """Move a tartaruga (t) para uma posição(length1, length2) unidades 
    sem deixar rastro.
    """
    t.penup()
    t.goto(length1,length2)
    t.pendown()

#from __future__ import print_function, division
import math
import ColabTurtle.Turtle as mateus

mateus.initializeTurtle()
mateus.speed(10)
mateus.window_size = (900,500)


mover(mateus, 150, 100)
flor(mateus, 7, 100.0, 60.0)

mover(mateus, 300,300)
flor(mateus, 10, 100.0, 80.0)

mover(mateus,600, 100)
flor(mateus, 20, 160.0, 20.0)

#mateus.hidenturtle()
#turtle.mainloop()
# Out:
#       <svg width="900" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="150" y1="100" x2="150.0" y2="98.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="150.0" y1="98.0" x2="149.9401690676612" y2="96.000895135433" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="149.9401690676612" y1="96.000895135433" x2="149.82056075977113" y2="94.00447487589753" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="149.82056075977113" y1="94.00447487589753" x2="149.64128214196427" y2="92.01252628790705" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="149.64128214196427" y1="92.01252628790705" x2="149.40249369288378" y2="90.02683243522337" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="149.40249369288378" y1="90.02683243522337" x2="149.10440916053142" y2="88.04917078277312" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="149.10440916053142" y1="88.04917078277312" x2="148.74729537093415" y2="86.08131160557586" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="148.74729537093415" y1="86.08131160557586" x2="148.33147198929862" y2="84.12501640410825" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="148.33147198929862" y1="84.12501640410825" x2="147.85731123386762" y2="82.18203632752251" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="147.85731123386762" y1="82.18203632752251" x2="147.32523754273427" y2="80.25411060613081" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="147.32523754273427" y1="80.25411060613081" x2="146.73572719391245" y2="78.34296499455853" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="146.73572719391245" y1="78.34296499455853" x2="146.08930787900354" y2="76.4503102269602" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="146.08930787900354" y1="76.4503102269602" x2="145.38655823084085" y2="74.57784048568072" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="145.38655823084085" y1="74.57784048568072" x2="144.628107305535" y2="72.72723188473273" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="144.628107305535" y1="72.72723188473273" x2="143.8146340193834" y2="70.90014096944753" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="143.8146340193834" y1="70.90014096944753" x2="142.94686654114827" y2="69.09820323364269" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="142.94686654114827" y1="69.09820323364269" x2="142.025581640247" y2="67.32303165563359" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="142.025581640247" y1="67.32303165563359" x2="141.05160399143827" y2="65.57621525439933" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="141.05160399143827" y1="65.57621525439933" x2="140.02580543662646" y2="63.8593176671956" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="140.02580543662646" y1="63.8593176671956" x2="138.9491042044451" y2="62.17387574988752" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="138.9491042044451" y1="62.17387574988752" x2="137.82246408831784" y2="60.521398201255536" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="137.82246408831784" y1="60.521398201255536" x2="136.6468935837329" y2="58.90336421250564" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="136.6468935837329" y1="58.90336421250564" x2="135.42344498550287" y2="57.32122214319296" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="135.42344498550287" y1="57.32122214319296" x2="134.1532134458185" y2="55.77638822474377" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="134.1532134458185" y1="55.77638822474377" x2="132.83733599393906" y2="54.270245292736554" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="132.83733599393906" y1="54.270245292736554" x2="131.47699051839723" y2="52.80414154907 ...

# %% [markdown]
# **Questão 02** - Escreva um conjunto apropriadamente geral de funções que podem desenhar formas como na figura:
#
# ![shapes](https://github.com/malbouis/Python_intro/blob/master/aulas_2019/pics/shapes_turtle.png?raw=1)

# %%
import math

def isosceles(t,r,ang):
    """Desenhe um triangulo isosceles.
    A tartaruga inicia e termina no pico, 
    t:turtle
    r: comprimentos iguais de pernas
    ang: angulo de meio pico em graus
    """
    y = r * math.sin(ang * math.pi / 180)

    t.right(ang)
    t.forward(r)
    t.left(90+ang)
    t.forward(int(2*y))
    t.left(90+ang)
    t.forward(r)
    t.left(180-ang)

def polypie(t,n,r):
    """Desenhe um torta dividida em segmentos radiais.
    t: turtle
    n: number of segments
    r: comprimento da barra radial
    """

    ang = 360.0 / n 
    for i in range(n):
        isosceles(t,r,ang/2)
        t.left(ang)


def draw_pie(t,n,r):
    """Desenhe uma torta, então mova na posição para direita.
    t: Turtle
    n: number of segments
    r: length of the radial spokes
    """

    polypie(t,n,r)
    t.penup()
    t.forward(r*2 + 10)
    t.pendown()

def mover(t, length1,length2):
    """Move a tartaruga (t) para uma posição(length1, length2) unidades 
    sem deixar rastro.
    """
    t.penup()
    t.goto(length1,length2)
    t.pendown()




import ColabTurtle.Turtle as mateus

mateus.initializeTurtle()
mover(mateus,100,400)

#desenhe pedaços de poligonos com diversas quantidades
size = 40
draw_pie(mateus,5,size)
draw_pie(mateus,6,size)
draw_pie(mateus,7,size)
draw_pie(mateus,8,size)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="100" y1="400" x2="123.51141009169892" y2="367.6393202250021" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="123.51141009169892" y1="367.6393202250021" x2="76.51141009169892" y2="367.6393202250021" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="76.51141009169892" y1="367.6393202250021" x2="100.02282018339784" y2="400.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="100.02282018339784" y1="400.0" x2="76.5114100916989" y2="367.6393202250021" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="76.5114100916989" y1="367.6393202250021" x2="61.98761135607638" y2="412.3389764908743" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="61.98761135607638" y1="412.3389764908743" x2="100.02987200788252" y2="399.9782967158764" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="100.02987200788252" y1="399.9782967158764" x2="61.98761135607638" y2="412.3389764908743" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="61.98761135607638" y1="412.3389764908743" x2="100.0114100916989" y2="439.96488334862056" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="100.0114100916989" y1="439.96488334862056" x2="100.01141009169889" y2="399.96488334862056" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="100.01141009169889" y1="399.96488334862056" x2="100.01141009169889" y2="439.96488334862056" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="100.01141009169889" y1="439.96488334862056" x2="138.0352088273214" y2="412.3389764908743" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="138.0352088273214" y1="412.3389764908743" x2="99.99294817551527" y2="399.9782967158764" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="99.99294817551527" y1="399.9782967158764" x2="138.0352088273214" y2="412.3389764908743" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="138.0352088273214" y1="412.3389764908743" x2="123.51141009169888" y2="367.6393202250021" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="123.51141009169888" y1="367.6393202250021" x2="99.99999999999996" y2="400.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="99.99999999999994" y1="310.0" x2="119.99999999999994" y2="275.3589838486225" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="119.99999999999994" y1="275.3589838486225" x2="80.99999999999994" y2="275.3589838486225" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="80.99999999999994" y1="275.3589838486225" x2="100.99999999999994" y2="310.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="100.99999999999994" y1="310.0" x2="80.99999999999993" y2="275.3589838486225" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="80.99999999999993" y1="275.3589838486225" x2="61.499999999999936" y2="309.1339745962156" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="61.499999999999936" y1="309.1339745962156" x2="101.49999999999994" y2="309.1339745962156" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="101.49999999999994" y1="309.1339745962156" x2="61.49999999999994" y2="309.1339745962156" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="61.49999999999994" y1="309.1339745962156" x2="80.99999999999994" y2="342.9089653438087" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="80.99999999999994" y1="342.9089653438087" x2="100.99999999999994" y2="308.26794919243116" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="100.99999999999994" y1="308.26794919243116" x2="80.99999999999994" y2="342.9089653438087" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="80.99999999999994" y1="342.9089653438087" x2="119.99999999999994" y2="342.9089653438087" stroke-linecap= ...

# %% [markdown]
# **Exercício 3** - Adicione instruções para desenhar o talo e folha da flor. Faça refatoração apropriada para a interface da flor completa fica "limpa".

# %%
def polyline(t, n, length, ang):
    """ Desenha n segmentos de linha com o tamanho e angulo
    (em graus) dados entre eles. t é uma tartaruga"""
    for i in range(n):
        t.forward(int(length))
        t.left(ang)

def arc(t, r, ang):
    arc_length = 2 * math.pi * r * ang / 360
    n = int(arc_length / 3) + 1
    step_length = arc_length / n 
    step_ang = float(ang) / n
    polyline(t, n, step_length, step_ang)
def petala(t, r, ang):
    """Desenha uma petola usando dois arcos.

      t -> é uma tartaruga
      r -> é o raio de um arco
    ang -> é o angulo (em graus) do arco
    """
    for i in range(2):
        arc(t, r, ang)
        t.left(180-ang)


def flor(t, n, r, ang):
    """ Desenha uma flor com n petolas.

    t -> tartaruga
    n -> números de petalas
    r -> raio do arco
    ang -> angulo (em graus) que o arco tem
    """
    for i in range(n):
        petala(t, r, ang)
        t.left(360/n)
    

#length1 e length 2 aceitam somente valores positivos
#Observe que a screen (tela) o valor (0,0) para (x,y) indica o canto superior esquerdo
#da screen.
def mover(t, length1,length2):
    """Move a tartaruga (t) para uma posição(length1, length2) unidades 
    sem deixar rastro.
    """
    t.penup()
    t.goto(length1,length2)
    t.pendown()

#from __future__ import print_function, division
import math
import ColabTurtle.Turtle as mateus

mateus.initializeTurtle()
mateus.speed(10)
mateus.window_size = (900,500)


mover(mateus, 150, 100)
flor(mateus, 7, 100.0, 60.0)
mateus.left(180)
arc(mateus, 600,20)
mateus.left(110)
flor(mateus, 1, 100.0,60)
mateus.right(110)
arc(mateus, 600,20)
# Out:
#       <svg width="900" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="150" y1="100" x2="150.0" y2="98.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="150.0" y1="98.0" x2="149.9401690676612" y2="96.000895135433" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="149.9401690676612" y1="96.000895135433" x2="149.82056075977113" y2="94.00447487589753" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="149.82056075977113" y1="94.00447487589753" x2="149.64128214196427" y2="92.01252628790705" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="149.64128214196427" y1="92.01252628790705" x2="149.40249369288378" y2="90.02683243522337" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="149.40249369288378" y1="90.02683243522337" x2="149.10440916053142" y2="88.04917078277312" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="149.10440916053142" y1="88.04917078277312" x2="148.74729537093415" y2="86.08131160557586" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="148.74729537093415" y1="86.08131160557586" x2="148.33147198929862" y2="84.12501640410825" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="148.33147198929862" y1="84.12501640410825" x2="147.85731123386762" y2="82.18203632752251" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="147.85731123386762" y1="82.18203632752251" x2="147.32523754273427" y2="80.25411060613081" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="147.32523754273427" y1="80.25411060613081" x2="146.73572719391245" y2="78.34296499455853" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="146.73572719391245" y1="78.34296499455853" x2="146.08930787900354" y2="76.4503102269602" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="146.08930787900354" y1="76.4503102269602" x2="145.38655823084085" y2="74.57784048568072" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="145.38655823084085" y1="74.57784048568072" x2="144.628107305535" y2="72.72723188473273" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="144.628107305535" y1="72.72723188473273" x2="143.8146340193834" y2="70.90014096944753" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="143.8146340193834" y1="70.90014096944753" x2="142.94686654114827" y2="69.09820323364269" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="142.94686654114827" y1="69.09820323364269" x2="142.025581640247" y2="67.32303165563359" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="142.025581640247" y1="67.32303165563359" x2="141.05160399143827" y2="65.57621525439933" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="141.05160399143827" y1="65.57621525439933" x2="140.02580543662646" y2="63.8593176671956" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="140.02580543662646" y1="63.8593176671956" x2="138.9491042044451" y2="62.17387574988752" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="138.9491042044451" y1="62.17387574988752" x2="137.82246408831784" y2="60.521398201255536" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="137.82246408831784" y1="60.521398201255536" x2="136.6468935837329" y2="58.90336421250564" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="136.6468935837329" y1="58.90336421250564" x2="135.42344498550287" y2="57.32122214319296" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="135.42344498550287" y1="57.32122214319296" x2="134.1532134458185" y2="55.77638822474377" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="134.1532134458185" y1="55.77638822474377" x2="132.83733599393906" y2="54.270245292736554" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="132.83733599393906" y1="54.270245292736554" x2="131.47699051839723" y2="52.80414154907 ...
