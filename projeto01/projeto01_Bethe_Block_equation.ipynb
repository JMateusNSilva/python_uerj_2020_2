# %% [markdown]
# <a href="https://colab.research.google.com/github/JMateusNSilva/python_uerj_2020_2/blob/master/projeto01/projeto01_Bethe_Block_equation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Item 1** - Escreva uma função em Python chamada **def gamma(beta):** que tenha como argumento β e retorna γ. Teste-o para um valor de β, como por exemplo, 0,6.

# %%
def gamma(beta):
    """Calcula um valor de gamma quando inserido um valor para beta.
    """
    gamma = (1-beta**2)**(-1/2)        # beta^2 = u^2/c^2 u-veloc. particula, c - veloc. luz.
    return gamma

gamma(0.6)
# Out:
# 1.25

# %%
# %%writefile função_gamma.py
def gamma(beta):
    gamma = (1-beta**2)**(-1/2)        # beta^2 = u^2/c^2 u-veloc. particula, c - veloc. luz.
    return gamma
# Out:
# Overwriting função_gamma.py

# %%
# %cat função_gamma.py
# Out:
# def gamma(beta):
#     gamma = (1-beta**2)**(-1/2)        # beta^2 = u^2/c^2 u-veloc. particula, c - veloc. luz.
#     return gamma

# %% [markdown]
# **Item 2** - Certifique-se que sua função gamma(beta) pode aceitar um vetor de β e retornar um vetor compatível de γ.

# %%
import numpy as np
from função_gamma import gamma
# Beta varia entre valores de 0 até 1.
beta = np.arange(0.0,1.0,0.005)                              # Valor do vetor beta
#print(f'O valor de vetor beta é: \n {beta}')
gamma = gamma(beta)
print(f'O valor do vetor gamma é: \n {gamma}')
# Out:
# O valor do vetor gamma é:
#  [ 1.          1.0000125   1.00005     1.00011252  1.00020006  1.00031265
#   1.0004503   1.00061306  1.00080096  1.00101404  1.00125235  1.00151594
#   1.00180487  1.00211922  1.00245904  1.00282442  1.00321544  1.00363219
#   1.00407477  1.00454328  1.00503782  1.0055585   1.00610546  1.00667882
#   1.00727871  1.00790526  1.00855863  1.00923898  1.00994645  1.01068123
#   1.01144347  1.01223338  1.01305112  1.01389691  1.01477094  1.01567343
#   1.0166046   1.01756467  1.01855389  1.01957249  1.02062073  1.02169887
#   1.02280718  1.02394595  1.02511546  1.02631601  1.02754791  1.02881148
#   1.03010705  1.03143496  1.03279556  1.03418921  1.03561628  1.03707716
#   1.03857224  1.04010193  1.04166667  1.04326687  1.04490299  1.04657548
#   1.04828484  1.05003153  1.05181608  1.053639    1.05550083  1.05740211
#   1.05934343  1.06132537  1.06334853  1.06541353  1.06752103  1.06967167
#   1.07186616  1.07410518  1.07638947  1.07871978  1.08109688  1.08352156
#   1.08599464  1.08851698  1.09108945  1.09371295  1.09638841  1.0991168
#   1.10189911  1.10473635  1.1076296   1.11057994  1.11358851  1.11665647
#   1.11978502  1.12297542  1.12622896  1.12954697  1.13293084  1.13638198
#   1.13990188  1.14349207  1.14715414  1.15088973  1.15470054  1.15858833
#   1.16255494  1.16660226  1.17073226  1.17494699  1.17924856  1.18363918
#   1.18812114  1.19269682  1.19736868  1.20213931  1.20701137  1.21198767
#   1.21707109  1.22226466  1.22757154  1.23299501  1.2385385   1.24420558
#   1.25        1.25592566  1.26198664  1.26818722  1.27453185  1.28102523
#   1.28767225  1.29447805  1.30144802  1.30858782  1.31590339  1.32340098
#   1.33108717  1.33896886  1.34705334  1.3553483   1.36386181  1.37260245
#   1.38157925  1.39080175  1.40028008  1.41002496  1.42004774  1.4303605
#   1.44097604  1.45190802  1.46317094  1.47478029  1.48675258  1.49910549
#   1.51185789  1.52503004  1.53864364  1.55272203  1.56729031  1.58237554
#   1.59800693  1.61421605  1.63103709  1.64850718  1.66666667  1.68555951
#   1.70523372  1.72574181  1.74714139  1.76949582  1.79287493  1.81735593
#   1.84302445  1.86997571  1.89831599  1.92816432  1.9596545   1.99293759
#   2.02818479  2.06559112  2.1053798   2.14780774  2.19317232  2.24182002
#   2.29415734  2.35066482  2.41191535  2.4785983   2.55155182  2.63180678
#   2.72064781  2.81969956  2.93105191  3.0574464   3.20256308  3.37147825
#   3.57142857  3.81315712  4.11345035  4.5003516   5.02518908  5.79527588
#   7.08881205 10.01252349]

# %% [markdown]
# **Item 3** - A partir de um vetor de valores β variando de 0 a 0,995, faça um gráfico gamma versus **gamma** versus **beta**.

# %%
import numpy as np
import matplotlib.pyplot as plt
from função_gamma import gamma
# Beta varia entre valores de 0 até 1.
beta = np.arange(0.0,0.996,0.005)               # O intervalo inclui o ponto inicial (0) e exclui o ponto final(0.996)

gamma = gamma(beta)

#beta.shape
#print(len(gamma))
#type(gamma)
#print(f'gamma = \n {gamma}')
#print(f'beta = \n {beta}')

plt.ylabel('γ' ,fontsize= 'x-large', fontweight='bold')
plt.xlabel('β' , fontsize= 'x-large', fontweight='bold')
plt.grid()
plt.plot(beta, gamma,'red')
plt.show()

# %% [markdown]
# **Item 4** - Faça um gráfico γβ versus β. O que você observa?

# %%
import numpy as np
import matplotlib.pyplot as plt
from função_gamma import gamma
# Beta varia entre valores de 0 até 1.
beta = np.arange(0,0.996,0.005)               # O intervalo inclui o ponto inicial (0) e exclui o ponto final(0.996)

gamma = gamma(beta)

gamma_beta = gamma*beta

#print(gamma_beta)

fig, ax1 = plt.subplots()
ax1.set_xlabel('β', fontsize= 'x-large', fontweight='bold')
ax1.set_ylabel('γβ', fontsize= 'x-large', fontweight= 'bold')
axi=plt.grid()
ax1=plt.plot(beta, gamma_beta, 'blue')



fig, ax6 = plt.subplots()
plt.grid()
ax6=plt.plot(beta,gamma, 'red', label='γ vs. β')
ax6=plt.plot( beta,gamma_beta, 'blue', label='γβ vs. β')
ax6=plt.legend()




#fig,ax2 = plt.subplots()
#plt.grid()
#ax2.set_ylabel('ln(γβ)')
#ax2.set_xlabel('ln(β)')
#ax2.set_xscale('log')
#ax2.set_yscale('log')
#ax2=plt.plot( beta, gamma_beta, 'blue')

# %% [markdown]
# **Item 5** - Trace o argumento do log natural na equação de Bethe-Block em uma função de γβ. Faça o argumento ser uma nova função **ln_argumetent()**. Para você: essa função deve aceitar β ou γ como argumento, ou ambos, ou seu produto? Observe que pode ser muito difícil obter β com uma boa precisão a partir γ em baixas velocidades; o oposto é difícil em velocidade muitos altas. Faça o gráfico para um intervalo de 0,1 a 100.

# %%
def ln_argument(valor):
    # Traçando o argumento do ln da equação de Bethe-Block.
    # constantes utilizadas.
    mc2 = 0.5110                             # Mev - massa do eletron - m_e * c^2.
    I = 29*10**(-5)                          # I/Z aprox 10^-5 onde Z é o número atômico que para o cobre Z=29. 
    x = (2*mc2 * valor**2) / I                 # x é o argumento do ln da equação de Bethe-Block.
    return x

x = ln_argument(gamma_beta)
plt.grid()
plt.plot(gamma_beta, x, 'blue')
plt.title('Gráfico: x vs. γβ')
plt.xlabel('γβ')
plt.ylabel('x')
# Out:
# Text(0, 0.5, 'x')

# %%
x = ln_argument(gamma_beta)                 # Este é o argumento do ln da equação de Bethe-Block

fig, ax4 = plt.subplots()

#ax4.set_xlim(0.1,100.1)                     # Limita o eixo x entre os valores de 0.1 até 100
ax4.set_ylim(0.1, 100.1)                     # reajusta o valor do eixo y
ax4.set_title('Gráfico: x vs. γβ',fontsize='x-large', fontweight='bold')
ax4.set_xlabel('γβ',fontsize='x-large', fontweight='bold')
ax4.set_ylabel('x', fontsize='x-large', fontweight='bold')
ax4=plt.grid()
ax4=plt.plot( gamma_beta, x, 'blue')

# %% [markdown]
# **Item 6** Esse gráfico não mostra a região de interesse para valores baixos de β. Faça o plot com uma escala logarítimica no eixo vertical? Dica: procure na ajuda do matplotlib a função semilog(). Ficou melhor? Talvez ambos os eixos.

# %%
x = ln_argument(gamma_beta)                 # Este é o argumento do ln da equação de Bethe-Block

fig, ax3 = plt.subplots()

# Gráfico 
ax3.set_title('Gráfico: x vs. γβ',fontsize='x-large', fontweight='bold')
ax3.set_xlabel('γβ',fontsize='x-large', fontweight='bold')
ax3.set_ylabel('x', fontsize='x-large', fontweight='bold')
ax3.set_yscale('log')
ax3=plt.grid()
ax3=plt.plot( gamma_beta, x, 'blue')
#ax2.set_xscale('log')

fig, ax4 = plt.subplots()

ax4.set_title('Gráfico: ln(x) vs. γβ',fontsize='x-large', fontweight='bold')
ax4.set_xlabel('γβ',fontsize='x-large', fontweight='bold')
ax4.set_ylabel('ln(x)', fontsize='x-large', fontweight='bold')
ax4.set_yscale('log')
#ax4.set_ylim(0.1,100.1)                     # Limita o eixo x entre os valores de 0.1 até 100
ax4=plt.grid()
ax4=plt.plot( gamma_beta, x, 'blue')

fig, ax5 = plt.subplots()

ax5.set_title('Gráfico: ln(x) vs. ln(γβ)',fontsize='x-large', fontweight='bold')
ax5.set_xlabel('ln(γβ)',fontsize='x-large', fontweight='bold')
ax5.set_ylabel('ln(x)', fontsize='x-large', fontweight='bold')
ax5.set_xscale('log')
ax5.set_yscale('log')
#ax5.set_ylim(0.1,100.1)                     # Limita o eixo y entre os valores de 0.1 até 100
ax5=plt.grid()
ax5=plt.plot( gamma_beta, x, 'blue')

fig, ax7=plt.subplots()
ax7.set_title('Gráfico: ln(x) vs. ln(γβ)',fontsize='x-large', fontweight='bold')
ax7.set_xlabel('ln(γβ)',fontsize='x-large', fontweight='bold')
ax7.set_ylabel('ln(x)', fontsize='x-large', fontweight='bold')
ax7.set_xscale('log')
ax7.set_yscale('log')
ax7.set_ylim(0.1,100.1)                     # Limita o eixo y entre os valores de 0.1 até 100
ax7=plt.grid()
ax7=plt.plot( gamma_beta, x, 'blue')

# %%
# Usando semilogy() command

x = ln_argument(gamma_beta)                 # Este é o argumento do ln da equação de Bethe-Block




fig, ax4 = plt.subplots()

ax4.set_title('Gráfico: ln(x) vs. γβ',fontsize='x-large', fontweight='bold')
ax4.set_xlabel('γβ',fontsize='x-large', fontweight='bold')
ax4.set_ylabel('ln(x)', fontsize='x-large', fontweight='bold')
ax4.semilogy(gamma_beta,x)
#ax4.set_yscale('log')
#ax4.set_ylim(0.1,100.1)                     # Limita o eixo x entre os valores de 0.1 até 100
ax4=plt.grid()
#ax4=plt.plot( gamma_beta, x, 'blue')

fig, ax5 = plt.subplots()

ax5.set_title('Gráfico: ln(x) vs. ln(γβ)',fontsize='x-large', fontweight='bold')
ax5.set_xlabel('ln(γβ)',fontsize='x-large', fontweight='bold')
ax5.set_ylabel('ln(x)', fontsize='x-large', fontweight='bold')
ax5.semilogy(gamma_beta,x)
ax5.semilogx(gamma_beta,x)
#ax5.set_xscale('log')
#ax5.set_yscale('log')
#ax5.set_ylim(0.1,100.1)                     # Limita o eixo y entre os valores de 0.1 até 100
ax5=plt.grid()
ax5=plt.plot( gamma_beta, x, 'blue')

# %% [markdown]
# **Item 7** - Provável que agora, seu valores γβ não estão uniformemente espaçado no gráfico. Faça um vetor de valores γβ que tenham um logarítimo uniformemente espaçado de 0,1 até 100. Repita o gráfico mais uma vez usando os novos argumentos. Uma identidade útil aqui é $\gamma^2 = (\gamma \beta)^2 + 1$.

# %%
x = ln_argument(gamma_beta)                 # Este é o argumento do ln da equação de Bethe-Block

fig, ax5 = plt.subplots()

ax5.set_title('Gráfico: ln(γβ) vs. ln(x)',fontsize='x-large', fontweight='bold')
ax5.set_xlabel('ln(γβ)',fontsize='x-large', fontweight='bold')
ax5.set_ylabel('ln(x)', fontsize='x-large', fontweight='bold')
ax5.set_xscale('log')
ax5.set_yscale('log')
ax5.set_xlim(0.1,100.1)                     # Limita o eixo x entre os valores de 0.1 até 100
ax5=plt.grid()
ax5=plt.plot( gamma_beta, x, 'blue')

# %% [markdown]
